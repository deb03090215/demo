# %%
import os
os.chdir('/content/drive/MyDrive/workspace/')

# %%
! pwd
# Out:
# /content/drive/My Drive/workspace

# %%
! git config --global user.email "deb03090215@gmail.com"
! git config --global user.name "deb03090215"
! git config --list
# Out:
# user.email=deb03090215@gmail.com
# user.name=deb03090215
# core.repositoryformatversion=0
# core.filemode=true
# core.bare=false
# core.logallrefupdates=true

# %%
! git init
# Out:
# Reinitialized existing Git repository in /content/.git/

# %%
! git add -A
! git commit -m "first commit"
# Out:
# git: 'add-A' is not a git command. See 'git --help'.
# On branch master
#
# Initial commit
#
# Untracked files:
# 	.config/
# 	sample_data/
#
# nothing added to commit but untracked files present
